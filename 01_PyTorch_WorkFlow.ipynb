# %% [markdown]
# # work flow

# %%
what_were_covering = {1: "data (prepare and load",
                      2: "build model",
                      3: "fitting the model to data(training)",
                      4: "making predictions and evaluating a model(inference",
                      5: "saving and loading the model",
                      6: "put it all together"}

what_were_covering
# Out:
# {1: 'data (prepare and load',
#  2: 'build model',
#  3: 'fitting the model to data(training)',
#  4: 'making predictions and evaluating a model(inference',
#  5: 'saving and loading the model',
#  6: 'put it all together'}

# %%
import torch
from torch import nn  # nn contains all of pytorch's building blocks
import matplotlib.pyplot as plt

torch.__version__
# Out:
# '2.0.1+cu118'

# %% [markdown]
# ## 1. preparing data
# * Excel sheet
# * images of any kind
# * videos
# * DNA
# * text
#
# 1. get data to a numerical representation
# 2. build a model to learn a patterns in that numerical representation

# %%
weight = 0.7
bias = 0.3

start = 0
end = 1
step = 0.02
X = torch.arange(start, end, step).unsqueeze(
    dim=1)  # it needs another dimension which makes it some row with one column
y = weight * X + bias

X[:10], y[:10]
# Out:
# (tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800],
#          [0.1000],
#          [0.1200],
#          [0.1400],
#          [0.1600],
#          [0.1800]]),
#  tensor([[0.3000],
#          [0.3140],
#          [0.3280],
#          [0.3420],
#          [0.3560],
#          [0.3700],
#          [0.3840],
#          [0.3980],
#          [0.4120],
#          [0.4260]]))

# %%
len(X), len(y)
# Out:
# (50, 50)

# %% [markdown]
# ## split data

# %%
train_split = int(0.8 * len(X))
X_train, y_train = X[:train_split], y[:train_split]
X_test, y_test = X[train_split:], y[train_split:],

len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (40, 40, 10, 10)

# %% [markdown]
# # Vitalize

# %%
def plot_predictions(train_data=X_train, train_labels=y_train, test_data=X_test, test_labels=y_test, predictions=None):
    plt.figure(figsize=(10, 7))
    plt.scatter(train_data, train_labels, c="b", s=4, label="Training data")

    plt.scatter(test_data, test_labels, c="g", s=4, label="Testing data")

    if predictions is not None:
        plt.scatter(test_data, predictions, c='r', s=4, label="Predictions")

    plt.legend(prop={"size": 14})

# %%
plot_predictions()

# %% [markdown]
# # building our first pytorch model

# %%
class LinearRegressionModel(nn.Module):  # almost Everything in pytorch inherit from nn.Module
    def __init__(self):
        super().__init__()
        self.weights = nn.Parameter(
            torch.randn(1, requires_grad=True, dtype=torch.float))  #requared_grad default is True
        self.bias = nn.Parameter(torch.randn(1, requires_grad=True, dtype=torch.float))

    def forward(self, x: torch.Tensor) -> torch.Tensor:  # x is the input
        return self.weights * x + self.bias

# %%
seed = 42
torch.manual_seed(seed)

model_0 = LinearRegressionModel()

list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %%
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.3367])), ('bias', tensor([0.1288]))])

# %%
with torch.inference_mode():
    y_pred = model_0(X_test)

y_pred
# Out:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]])

# %%
plot_predictions(predictions=y_pred)

# %%
loss_fn = nn.L1Loss()
optimizer = torch.optim.SGD(model_0.parameters(), lr=0.01)

# %%
epochs = 1000
for epoch in range(epochs):
    model_0.train()  # it is its default.. not necessary
    y_pred = model_0(X_train)
    loss = loss_fn(y_pred, y_train)
    print(f"loss is {loss}")
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    model_0.eval()
    print(model_0.state_dict())
# Out:
# loss is 0.31288138031959534
# OrderedDict([('weights', tensor([0.3406])), ('bias', tensor([0.1388]))])
# loss is 0.3013603389263153
# OrderedDict([('weights', tensor([0.3445])), ('bias', tensor([0.1488]))])
# loss is 0.28983935713768005
# OrderedDict([('weights', tensor([0.3484])), ('bias', tensor([0.1588]))])
# loss is 0.2783183455467224
# OrderedDict([('weights', tensor([0.3523])), ('bias', tensor([0.1688]))])
# loss is 0.26679736375808716
# OrderedDict([('weights', tensor([0.3562])), ('bias', tensor([0.1788]))])
# loss is 0.2552763521671295
# OrderedDict([('weights', tensor([0.3601])), ('bias', tensor([0.1888]))])
# loss is 0.24375534057617188
# OrderedDict([('weights', tensor([0.3640])), ('bias', tensor([0.1988]))])
# loss is 0.23223432898521423
# OrderedDict([('weights', tensor([0.3679])), ('bias', tensor([0.2088]))])
# loss is 0.22071333229541779
# OrderedDict([('weights', tensor([0.3718])), ('bias', tensor([0.2188]))])
# loss is 0.20919232070446014
# OrderedDict([('weights', tensor([0.3757])), ('bias', tensor([0.2288]))])
# loss is 0.1976713240146637
# OrderedDict([('weights', tensor([0.3796])), ('bias', tensor([0.2388]))])
# loss is 0.18615034222602844
# OrderedDict([('weights', tensor([0.3835])), ('bias', tensor([0.2488]))])
# loss is 0.1746293306350708
# OrderedDict([('weights', tensor([0.3874])), ('bias', tensor([0.2588]))])
# loss is 0.16310831904411316
# OrderedDict([('weights', tensor([0.3913])), ('bias', tensor([0.2688]))])
# loss is 0.1515873372554779
# OrderedDict([('weights', tensor([0.3952])), ('bias', tensor([0.2788]))])
# loss is 0.14006635546684265
# OrderedDict([('weights', tensor([0.3991])), ('bias', tensor([0.2888]))])
# loss is 0.1285453587770462
# OrderedDict([('weights', tensor([0.4030])), ('bias', tensor([0.2988]))])
# loss is 0.11702437698841095
# OrderedDict([('weights', tensor([0.4069])), ('bias', tensor([0.3088]))])
# loss is 0.1060912236571312
# OrderedDict([('weights', tensor([0.4108])), ('bias', tensor([0.3178]))])
# loss is 0.09681284427642822
# OrderedDict([('weights', tensor([0.4146])), ('bias', tensor([0.3258]))])
# loss is 0.08908725529909134
# OrderedDict([('weights', tensor([0.4184])), ('bias', tensor([0.3333]))])
# loss is 0.08227583020925522
# OrderedDict([('weights', tensor([0.4222])), ('bias', tensor([0.3403]))])
# loss is 0.07638873159885406
# OrderedDict([('weights', tensor([0.4258])), ('bias', tensor([0.3463]))])
# loss is 0.07160007208585739
# OrderedDict([('weights', tensor([0.4293])), ('bias', tensor([0.3518]))])
# loss is 0.06747635453939438
# OrderedDict([('weights', tensor([0.4328])), ('bias', tensor([0.3568]))])
# loss is 0.06395438313484192
# OrderedDict([('weights', tensor([0.4361])), ('bias', tensor([0.3613]))])
# loss is 0.06097004935145378
# OrderedDict([('weights', tensor([0.4394])), ('bias', tensor([0.3653]))])
# loss is 0.05845819041132927
# OrderedDict([('weights', tensor([0.4425])), ('bias', tensor([0.3688]))])
# loss is 0.05635259300470352
# OrderedDict([('weights', tensor([0.4455])), ('bias', tensor([0.3718]))])
# loss is 0.0545857772231102
# OrderedDict([('weights', tensor([0.4483])), ('bias', tensor([0.3743]))])
# loss is 0.053148526698350906
# OrderedDict([('weights', tensor([0.4512])), ('bias', tensor([0.3768]))])
# loss is 0.05181945487856865
# OrderedDict([('weights', tensor([0.4539])), ('bias', tensor([0.3788]))])
# loss is 0.05069301277399063
# OrderedDict([('weights', tensor([0.4564])), ('bias', tensor([0.3803]))])
# loss is 0.0498228520154953
# OrderedDict([('weights', tensor([0.4590])), ('bias', tensor([0.3818]))])
# loss is 0.04895269125699997
# OrderedDict([('weights', tensor([0.4615])), ('bias', tensor([0.3833]))])
# loss is 0.04819351062178612
# OrderedDict([('weights', tensor([0.4639])), ('bias', tensor([0.3843]))])
# loss is 0.047531817108392715
# OrderedDict([('weights', tensor([0.4662])), ('bias', tensor([0.3853]))])
# loss is 0.04692792519927025
# OrderedDict([('weights', tensor([0.4684])), ('bias', tensor([0.3858]))])
# loss is 0.04642331600189209
# OrderedDict([('weights', tensor([0.4706])), ('bias', tensor([0.3863]))])
# loss is 0.04591871052980423
# OrderedDict([('weights', tensor([0.4728])), ('bias', tensor([0.3868]))])
# loss is 0.04543796554207802
# OrderedDict([('weights', tensor([0.4748])), ('bias', tensor([0.3868]))])
# loss is 0.04503796249628067
# OrderedDict([('weights', tensor([0.4768])), ('bias', tensor([0.3868]))])
# loss is 0.04463795945048332
# OrderedDict([('weights', tensor([0.4788])), ('bias', tensor([0.3868]))])
# loss is 0.04423796385526657
# OrderedDict([('weights', tensor([0.4808])), ('bias', tensor([0.3868]))])
# loss is 0.04383796453475952
# OrderedDict([('weights', tensor([0.4828])), ('bias', tensor([0.3868]))])
# loss is 0.04343796148896217
# OrderedDict([('weights', tensor([0.4848])), ('bias', tensor([0.3868]))])
# loss is 0.043074630200862885
# OrderedDict([('weights', tensor([0.4866])), ('bias', tensor([0.3863]))])
# loss is 0.04272563382983208
# OrderedDict([('weights', tensor([0.4884])), ('bias', tensor([0.3858]))])
# loss is 0.04237663000822067
# OrderedDict([('weights', tensor([0.4902])), ('bias', tensor([0.3853]))])
# loss is 0.04202762991189957
# OrderedDict([('weights', tensor([0.4920])), ('bias', tensor([0.3848]))])
# loss is 0.04167863354086876
# OrderedDict([('weights', tensor([0.4938])), ('bias', tensor([0.3843]))])
# loss is 0.04132963344454765
# OrderedDict([('weights', tensor([0.4956])), ('bias', tensor([0.3838]))])
# loss is 0.04098063334822655
# OrderedDict([('weights', tensor([0.4974])), ('bias', tensor([0.3833]))])
# loss is 0.04063162952661514
# OrderedDict([('weights', tensor([0.4992])), ('bias', tensor([0.3828]))])
# loss is 0.040282636880874634
# OrderedDict([('weights', tensor([0.5010])), ('bias', tensor([0.3823]))])
# loss is 0.039933640509843826
# OrderedDict([('weights', tensor([0.5028])), ('bias', tensor([0.3818]))])
# loss is 0.03958464413881302
# OrderedDict([('weights', tensor([0.5046])), ('bias', tensor([0.3813]))])
# loss is 0.03923564404249191
# OrderedDict([('weights', tensor([0.5064])), ('bias', tensor([0.3808]))])
# loss is 0.03888664394617081
# OrderedDict([('weights', tensor([0.5082])), ('bias', tensor([0.3803]))])
# loss is 0.0385376438498497
# OrderedDict([('weights', tensor([0.5100])), ('bias', tensor([0.3798]))])
# loss is 0.03818932920694351
# OrderedDict([('weights', tensor([0.5116])), ('bias', tensor([0.3788]))])
# loss is 0.03785243630409241
# OrderedDict([('weights', tensor([0.5134])), ('bias', tensor([0.3783]))])
# loss is 0.0375034399330616
# OrderedDict([('weights', tensor([0.5152])), ('bias', tensor([0.3778]))])
# loss is 0.037164121866226196
# OrderedDict([('weights', tensor([0.5168])), ('bias', tensor([0.3768]))])
# loss is 0.03681822493672371
# OrderedDict([('weights', tensor([0.5186])), ('bias', tensor([0.3763]))])
# loss is 0.03647511452436447
# OrderedDict([('weights', tensor([0.5202])), ('bias', tensor([0.3753]))])
# loss is 0.03613303601741791
# OrderedDict([('weights', tensor([0.5220])), ('bias', tensor([0.3748]))])
# loss is 0.03578609973192215
# OrderedDict([('weights', tensor([0.5236])), ('bias', tensor([0.3738]))])
# loss is 0.03544783592224121
# OrderedDict([('weights', tensor([0.5254])), ('bias', tensor([0.3733]))])
# loss is 0.035098835825920105
# OrderedDict([('weights', tensor([0.5272])), ('bias', tensor([0.3728]))])
# loss is 0.03476089984178543
# OrderedDict([('weights', tensor([0.5288])), ('bias', tensor([0.3718]))])
# loss is 0.03441363573074341
# OrderedDict([('weights', tensor([0.5306])), ('bias', tensor([0.3713]))])
# loss is 0.03407188132405281
# OrderedDict([('weights', tensor([0.5322])), ('bias', tensor([0.3703]))])
# loss is 0.03372843936085701
# OrderedDict([('weights', tensor([0.5340])), ('bias', tensor([0.3698]))])
# loss is 0.03338287025690079
# OrderedDict([('weights', tensor([0.5355])), ('bias', tensor([0.3688]))])
# loss is 0.033043231815099716
# OrderedDict([('weights', tensor([0.5373])), ('bias', tensor([0.3683]))])
# loss is 0.03269423171877861
# OrderedDict([('weights', tensor([0.5391])), ('bias', tensor([0.3678]))])
# loss is 0.032357655465602875
# OrderedDict([('weights', tensor([0.5407])), ('bias', tensor([0.3668]))])
# loss is 0.03200903534889221
# OrderedDict([('weights', tensor([0.5425])), ('bias', tensor([0.3663]))])
# loss is 0.03166864812374115
# OrderedDict([('weights', tensor([0.5441])), ('bias', tensor([0.3653]))])
# loss is 0.03132382780313492
# OrderedDict([('weights', tensor([0.5459])), ('bias', tensor([0.3648]))])
# loss is 0.030979642644524574
# OrderedDict([('weights', tensor([0.5475])), ('bias', tensor([0.3638]))])
# loss is 0.030638623982667923
# OrderedDict([('weights', tensor([0.5493])), ('bias', tensor([0.3633]))])
# loss is 0.0302906334400177
# OrderedDict([('weights', tensor([0.5509])), ('bias', tensor([0.3623]))])
# loss is 0.029953425750136375
# OrderedDict([('weights', tensor([0.5527])), ('bias', tensor([0.3618]))])
# loss is 0.02960442565381527
# OrderedDict([('weights', tensor([0.5545])), ('bias', tensor([0.3613]))])
# loss is 0.029265418648719788
# OrderedDict([('weights', tensor([0.5561])), ('bias', tensor([0.3603]))])
# loss is 0.028919223695993423
# OrderedDict([('weights', tensor([0.5579])), ('bias', tensor([0.3598]))])
# loss is 0.028576409444212914
# OrderedDict([('weights', tensor([0.5595])), ('bias', tensor([0.3588]))])
# loss is 0.028234025463461876
# OrderedDict([('weights', tensor([0.5613])), ('bias', tensor([0.3583]))])
# loss is 0.02788739837706089
# OrderedDict([('weights', tensor([0.5629])), ('bias', tensor([0.3573]))])
# loss is 0.02754882536828518
# OrderedDict([('weights', tensor([0.5647])), ('bias', tensor([0.3568]))])
# loss is 0.027199819684028625
# OrderedDict([('weights', tensor([0.5665])), ('bias', tensor([0.3563]))])
# loss is 0.026862185448408127
# OrderedDict([('weights', tensor([0.5681])), ('bias', tensor([0.3553]))])
# loss is 0.02651461586356163
# OrderedDict([('weights', tensor([0.5699])), ('bias', tensor([0.3548]))])
# loss is 0.026173178106546402
# OrderedDict([('weights', tensor([0.5715])), ('bias', tensor([0.3538]))])
# loss is 0.025829419493675232
# OrderedDict([('weights', tensor([0.5733])), ('bias', tensor([0.3533]))])
# loss is 0.02548416517674923
# OrderedDict([('weights', tensor([0.5748])), ('bias', tensor([0.3523]))])
# loss is 0.025144213810563087
# OrderedDict([('weights', tensor([0.5766])), ('bias', tensor([0.3518]))])
# loss is 0.02479521557688713
# OrderedDict([('weights', tensor([0.5784])), ('bias', tensor([0.3513]))])
# loss is 0.024458957836031914
# OrderedDict([('weights', tensor([0.5800])), ('bias', tensor([0.3503]))])
# loss is 0.024110013619065285
# OrderedDict([('weights', tensor([0.5818])), ('bias', tensor([0.3498]))])
# loss is 0.02376994863152504
# OrderedDict([('weights', tensor([0.5834])), ('bias', tensor([0.3488]))])
# loss is 0.02342480979859829
# OrderedDict([('weights', tensor([0.5852])), ('bias', tensor([0.3483]))])
# loss is 0.023080935701727867
# OrderedDict([('weights', tensor([0.5868])), ('bias', tensor([0.3473]))])
# loss is 0.022739607840776443
# OrderedDict([('weights', tensor([0.5886])), ('bias', tensor([0.3468]))])
# loss is 0.022391926497220993
# OrderedDict([('weights', tensor([0.5902])), ('bias', tensor([0.3458]))])
# loss is 0.022054409608244896
# OrderedDict([('weights', tensor([0.5920])), ('bias', tensor([0.3453]))])
# loss is 0.02170540764927864
# OrderedDict([('weights', tensor([0.5938])), ('bias', tensor([0.3448]))])
# loss is 0.021366719156503677
# OrderedDict([('weights', tensor([0.5954])), ('bias', tensor([0.3438]))])
# loss is 0.021020207554101944
# OrderedDict([('weights', tensor([0.5972])), ('bias', tensor([0.3433]))])
# loss is 0.020677709951996803
# OrderedDict([('weights', tensor([0.5988])), ('bias', tensor([0.3423]))])
# loss is 0.02033500373363495
# OrderedDict([('weights', tensor([0.6006])), ('bias', tensor([0.3418]))])
# loss is 0.01998869702219963
# OrderedDict([('weights', tensor([0.6022])), ('bias', tensor([0.3408]))])
# loss is 0.019649803638458252
# OrderedDict([('weights', tensor([0.6040])), ('bias', tensor([0.3403]))])
# loss is 0.019300809130072594
# OrderedDict([('weights', tensor([0.6058])), ('bias', tensor([0.3398]))])
# loss is 0.018963487818837166
# OrderedDict([('weights', tensor([0.6074])), ('bias', tensor([0.3388]))])
# loss is 0.01861560344696045
# OrderedDict([('weights', tensor([0.6092])), ('bias', tensor([0.3383]))])
# loss is 0.018274478614330292
# OrderedDict([('weights', tensor([0.6108])), ('bias', tensor([0.3373]))])
# loss is 0.017930403351783752
# OrderedDict([('weights', tensor([0.6126])), ('bias', tensor([0.3368]))])
# loss is 0.01758546568453312
# OrderedDict([('weights', tensor([0.6141])), ('bias', tensor([0.3358]))])
# loss is 0.017245199531316757
# OrderedDict([('weights', tensor([0.6159])), ('bias', tensor([0.3353]))])
# loss is 0.016896454617381096
# OrderedDict([('weights', tensor([0.6175])), ('bias', tensor([0.3343]))])
# loss is 0.01656000316143036
# OrderedDict([('weights', tensor([0.6193])), ('bias', tensor([0.3338]))])
# loss is 0.016210997477173805
# OrderedDict([('weights', tensor([0.6211])), ('bias', tensor([0.3333]))])
# loss is 0.01587124727666378
# OrderedDict([('weights', tensor([0.6227])), ('bias', tensor([0.3323]))])
# loss is 0.015525798313319683
# OrderedDict([('weights', tensor([0.6245])), ('bias', tensor([0.3318]))])
# loss is 0.015182236209511757
# OrderedDict([('weights', tensor([0.6261])), ('bias', tensor([0.3308]))])
# loss is 0.014840595424175262
# OrderedDict([('weights', tensor([0.6279])), ('bias', tensor([0.3303]))])
# loss is 0.01449323259294033
# OrderedDict([('weights', tensor([0.6295])), ('bias', tensor([0.3293]))])
# loss is 0.014155393466353416
# OrderedDict([('weights', tensor([0.6313])), ('bias', tensor([0.3288]))])
# loss is 0.013806397095322609
# OrderedDict([('weights', tensor([0.6331])), ('bias', tensor([0.3283]))])
# loss is 0.013468016870319843
# OrderedDict([('weights', tensor([0.6347])), ('bias', tensor([0.3273]))])
# loss is 0.013121193274855614
# OrderedDict([('weights', tensor([0.6365])), ('bias', tensor([0.3268]))])
# loss is 0.01277900766581297
# OrderedDict([('weights', tensor([0.6381])), ('bias', tensor([0.3258]))])
# loss is 0.012435992248356342
# OrderedDict([('weights', tensor([0.6399])), ('bias', tensor([0.3253]))])
# loss is 0.01208999752998352
# OrderedDict([('weights', tensor([0.6415])), ('bias', tensor([0.3243]))])
# loss is 0.011750795878469944
# OrderedDict([('weights', tensor([0.6433])), ('bias', tensor([0.3238]))])
# loss is 0.011401787400245667
# OrderedDict([('weights', tensor([0.6451])), ('bias', tensor([0.3233]))])
# loss is 0.011064787395298481
# OrderedDict([('weights', tensor([0.6467])), ('bias', tensor([0.3223]))])
# loss is 0.010716589167714119
# OrderedDict([('weights', tensor([0.6485])), ('bias', tensor([0.3218]))])
# loss is 0.010375778190791607
# OrderedDict([('weights', tensor([0.6501])), ('bias', tensor([0.3208]))])
# loss is 0.010031387209892273
# OrderedDict([('weights', tensor([0.6519])), ('bias', tensor([0.3203]))])
# loss is 0.009686763398349285
# OrderedDict([('weights', tensor([0.6534])), ('bias', tensor([0.3193]))])
# loss is 0.009346187114715576
# OrderedDict([('weights', tensor([0.6552])), ('bias', tensor([0.3188]))])
# loss is 0.008997755125164986
# OrderedDict([('weights', tensor([0.6568])), ('bias', tensor([0.3178]))])
# loss is 0.008660981431603432
# OrderedDict([('weights', tensor([0.6586])), ('bias', tensor([0.3173]))])
# loss is 0.008311985060572624
# OrderedDict([('weights', tensor([0.6604])), ('bias', tensor([0.3168]))])
# loss is 0.007972544990479946
# OrderedDict([('weights', tensor([0.6620])), ('bias', tensor([0.3158]))])
# loss is 0.007626785431057215
# OrderedDict([('weights', tensor([0.6638])), ('bias', tensor([0.3153]))])
# loss is 0.0072835334576666355
# OrderedDict([('weights', tensor([0.6654])), ('bias', tensor([0.3143]))])
# loss is 0.006941580679267645
# OrderedDict([('weights', tensor([0.6672])), ('bias', tensor([0.3138]))])
# loss is 0.006594526115804911
# OrderedDict([('weights', tensor([0.6688])), ('bias', tensor([0.3128]))])
# loss is 0.006256377790123224
# OrderedDict([('weights', tensor([0.6706])), ('bias', tensor([0.3123]))])
# loss is 0.005907376762479544
# OrderedDict([('weights', tensor([0.6724])), ('bias', tensor([0.3118]))])
# loss is 0.005569315515458584
# OrderedDict([('weights', tensor([0.6740])), ('bias', tensor([0.3108]))])
# loss is 0.005222178064286709
# OrderedDict([('weights', tensor([0.6758])), ('bias', tensor([0.3103]))])
# loss is 0.004880306776612997
# OrderedDict([('weights', tensor([0.6774])), ('bias', tensor([0.3093]))])
# loss is 0.004536976106464863
# OrderedDict([('weights', tensor([0.6792])), ('bias', tensor([0.3088]))])
# loss is 0.00419129803776741
# OrderedDict([('weights', tensor([0.6808])), ('bias', tensor([0.3078]))])
# loss is 0.0038517764769494534
# OrderedDict([('weights', tensor([0.6826])), ('bias', tensor([0.3073]))])
# loss is 0.0035027749836444855
# OrderedDict([('weights', tensor([0.6844])), ('bias', tensor([0.3068]))])
# loss is 0.0031660839449614286
# OrderedDict([('weights', tensor([0.6860])), ('bias', tensor([0.3058]))])
# loss is 0.002817571861669421
# OrderedDict([('weights', tensor([0.6878])), ('bias', tensor([0.3053]))])
# loss is 0.0024770735763013363
# OrderedDict([('weights', tensor([0.6894])), ('bias', tensor([0.3043]))])
# loss is 0.0021323717664927244
# OrderedDict([('weights', tensor([0.6912])), ('bias', tensor([0.3038]))])
# loss is 0.0017880648374557495
# OrderedDict([('weights', tensor([0.6927])), ('bias', tensor([0.3028]))])
# loss is 0.0014518328243866563
# OrderedDict([('weights', tensor([0.6947])), ('bias', tensor([0.3028]))])
# loss is 0.0011887758737429976
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# ...
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# loss is 0.008932482451200485
# OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# loss is 0.0025885067880153656
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])

# %%
with torch.inference_mode():
    y_pred = model_0(X_test)
    plot_predictions(predictions=y_pred)

# %%
# %load_ext autoreload
# %autoreload 2
import Neural_Network as nnn

model = nnn.Neural_Net()
model, data = nnn.flow(model, [X_train, y_train], [X_test, y_test], epochs=1000, learning_rate=0.01)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Epoch:10 | Loss:0.2382 | Test_loss:0.2817
# Epoch:20 | Loss:0.1230 | Test_loss:0.1469
# Epoch:30 | Loss:0.0093 | Test_loss:0.0171
# Epoch:40 | Loss:0.0033 | Test_loss:0.0068
# Epoch:50 | Loss:0.0052 | Test_loss:0.0040
# Epoch:60 | Loss:0.0052 | Test_loss:0.0040
# Epoch:70 | Loss:0.0052 | Test_loss:0.0040
# Epoch:80 | Loss:0.0052 | Test_loss:0.0040
# Epoch:90 | Loss:0.0052 | Test_loss:0.0040
# Epoch:100 | Loss:0.0052 | Test_loss:0.0040
# Epoch:110 | Loss:0.0052 | Test_loss:0.0040
# Epoch:120 | Loss:0.0052 | Test_loss:0.0040
# Epoch:130 | Loss:0.0052 | Test_loss:0.0040
# Epoch:140 | Loss:0.0052 | Test_loss:0.0040
# Epoch:150 | Loss:0.0052 | Test_loss:0.0040
# Epoch:160 | Loss:0.0052 | Test_loss:0.0040
# Epoch:170 | Loss:0.0052 | Test_loss:0.0040
# Epoch:180 | Loss:0.0052 | Test_loss:0.0040
# Epoch:190 | Loss:0.0052 | Test_loss:0.0040
# Epoch:200 | Loss:0.0052 | Test_loss:0.0040
# Epoch:210 | Loss:0.0052 | Test_loss:0.0040
# Epoch:220 | Loss:0.0052 | Test_loss:0.0040
# Epoch:230 | Loss:0.0052 | Test_loss:0.0040
# Epoch:240 | Loss:0.0052 | Test_loss:0.0040
# Epoch:250 | Loss:0.0052 | Test_loss:0.0040
# Epoch:260 | Loss:0.0052 | Test_loss:0.0040
# Epoch:270 | Loss:0.0052 | Test_loss:0.0040
# Epoch:280 | Loss:0.0052 | Test_loss:0.0040
# Epoch:290 | Loss:0.0052 | Test_loss:0.0040
# Epoch:300 | Loss:0.0052 | Test_loss:0.0040
# Epoch:310 | Loss:0.0052 | Test_loss:0.0040
# Epoch:320 | Loss:0.0052 | Test_loss:0.0040
# Epoch:330 | Loss:0.0052 | Test_loss:0.0040
# Epoch:340 | Loss:0.0052 | Test_loss:0.0040
# Epoch:350 | Loss:0.0052 | Test_loss:0.0040
# Epoch:360 | Loss:0.0052 | Test_loss:0.0040
# Epoch:370 | Loss:0.0052 | Test_loss:0.0040
# Epoch:380 | Loss:0.0052 | Test_loss:0.0040
# Epoch:390 | Loss:0.0052 | Test_loss:0.0040
# Epoch:400 | Loss:0.0052 | Test_loss:0.0040
# Epoch:410 | Loss:0.0052 | Test_loss:0.0040
# Epoch:420 | Loss:0.0052 | Test_loss:0.0040
# Epoch:430 | Loss:0.0052 | Test_loss:0.0040
# Epoch:440 | Loss:0.0052 | Test_loss:0.0040
# Epoch:450 | Loss:0.0052 | Test_loss:0.0040
# Epoch:460 | Loss:0.0052 | Test_loss:0.0040
# Epoch:470 | Loss:0.0052 | Test_loss:0.0040
# Epoch:480 | Loss:0.0052 | Test_loss:0.0040
# Epoch:490 | Loss:0.0052 | Test_loss:0.0040
# Epoch:500 | Loss:0.0052 | Test_loss:0.0040
# Epoch:510 | Loss:0.0052 | Test_loss:0.0040
# Epoch:520 | Loss:0.0052 | Test_loss:0.0040
# Epoch:530 | Loss:0.0052 | Test_loss:0.0040
# Epoch:540 | Loss:0.0052 | Test_loss:0.0040
# Epoch:550 | Loss:0.0052 | Test_loss:0.0040
# Epoch:560 | Loss:0.0052 | Test_loss:0.0040
# Epoch:570 | Loss:0.0052 | Test_loss:0.0040
# Epoch:580 | Loss:0.0052 | Test_loss:0.0040
# Epoch:590 | Loss:0.0052 | Test_loss:0.0040
# Epoch:600 | Loss:0.0052 | Test_loss:0.0040
# Epoch:610 | Loss:0.0052 | Test_loss:0.0040
# Epoch:620 | Loss:0.0052 | Test_loss:0.0040
# Epoch:630 | Loss:0.0052 | Test_loss:0.0040
# Epoch:640 | Loss:0.0052 | Test_loss:0.0040
# Epoch:650 | Loss:0.0052 | Test_loss:0.0040
# Epoch:660 | Loss:0.0052 | Test_loss:0.0040
# Epoch:670 | Loss:0.0052 | Test_loss:0.0040
# Epoch:680 | Loss:0.0052 | Test_loss:0.0040
# Epoch:690 | Loss:0.0052 | Test_loss:0.0040
# Epoch:700 | Loss:0.0052 | Test_loss:0.0040
# Epoch:710 | Loss:0.0052 | Test_loss:0.0040
# Epoch:720 | Loss:0.0052 | Test_loss:0.0040
# Epoch:730 | Loss:0.0052 | Test_loss:0.0040
# Epoch:740 | Loss:0.0052 | Test_loss:0.0040
# Epoch:750 | Loss:0.0052 | Test_loss:0.0040
# Epoch:760 | Loss:0.0052 | Test_loss:0.0040
# Epoch:770 | Loss:0.0052 | Test_loss:0.0040
# Epoch:780 | Loss:0.0052 | Test_loss:0.0040
# Epoch:790 | Loss:0.0052 | Test_loss:0.0040
# Epoch:800 | Loss:0.0052 | Test_loss:0.0040
# Epoch:810 | Loss:0.0052 | Test_loss:0.0040
# Epoch:820 | Loss:0.0052 | Test_loss:0.0040
# Epoch:830 | Loss:0.0052 | Test_loss:0.0040
# Epoch:840 | Loss:0.0052 | Test_loss:0.0040
# Epoch:850 | Loss:0.0052 | Test_loss:0.0040
# Epoch:860 | Loss:0.0052 | Test_loss:0.0040
# Epoch:870 | Loss:0.0052 | Test_loss:0.0040
# Epoch:880 | Loss:0.0052 | Test_loss:0.0040
# Epoch:890 | Loss:0.0052 | Test_loss:0.0040
# Epoch:900 | Loss:0.0052 | Test_loss:0.0040
# Epoch:910 | Loss:0.0052 | Test_loss:0.0040
# Epoch:920 | Loss:0.0052 | Test_loss:0.0040
# Epoch:930 | Loss:0.0052 | Test_loss:0.0040
# Epoch:940 | Loss:0.0052 | Test_loss:0.0040
# Epoch:950 | Loss:0.0052 | Test_loss:0.0040
# Epoch:960 | Loss:0.0052 | Test_loss:0.0040
# Epoch:970 | Loss:0.0052 | Test_loss:0.0040
# Epoch:980 | Loss:0.0052 | Test_loss:0.0040
# Epoch:990 | Loss:0.0052 | Test_loss:0.0040

# %%
nnn.test(model, X_test, y_test)
# Out:
# test loss is : 0.009510141797363758

# %%
plt.plot(data[0], data[1], label="Train_loss")
plt.plot(data[0], data[2], label="Test_loss")
plt.title("Training and test loss curves")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.legend()

# %% [markdown]
# # Saving Model

# %%
# first method 
from pathlib import Path

model_path = Path("models")
model_path.mkdir(parents=True, exist_ok=True)

model_name = "01_pytorch_workflow.pth"
model_save_path = model_path / model_name

print(f"save model to {model_path}")
torch.save(model.state_dict(), f=model_save_path)
# Out:
# save model to models

# %%
loaded_mode = nnn.Neural_Net()
loaded_mode.load_state_dict(torch.load(f=model_save_path))
loaded_mode.state_dict()
# Out:
# OrderedDict([('weight', tensor([0.6914])), ('bias', tensor([0.2982]))])

# %%
loaded_mode.eval()
with torch.inference_mode():
    loaded_mode_pred = loaded_mode(X_test)

loaded_mode_pred
# Out:
# tensor([[0.8513],
#         [0.8651],
#         [0.8789],
#         [0.8927],
#         [0.9066],
#         [0.9204],
#         [0.9342],
#         [0.9481],
#         [0.9619],
#         [0.9757]])

# %%
model.eval()
with torch.inference_mode():
    y_pred = model(X_test)

y_pred == loaded_mode_pred
# Out:
# tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])

# %% [markdown]
# # Redo everything in CUDA

# %% [markdown]
# # moduls

# %% [markdown]
# # data

# %%
weight = 0.7
bias = 0.3

star = 0
end = 1
step = 0.02

X = torch.arange(start, end, step).unsqueeze(dim=1)
y = weight * X + bias

# %%
import torch
from torch import nn
import matplotlib.pyplot as plt

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# # Split Data

# %%
train_split = int(0.8 * len(X))
X_train, y_train = X[:train_split], y[:train_split]
X_test, y_test = X[train_split:], y[train_split:]
nnn.plot_predictions([X_train, y_train], [X_test, y_test])

# %%
class Linear(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_layer = nn.Linear(in_features=1, out_features=1)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.linear_layer(x)


torch.manual_seed(42)
model_1 = Linear()
model_1, model_1.state_dict()
# Out:
# (Linear(
#    (linear_layer): Linear(in_features=1, out_features=1, bias=True)
#  ),
#  OrderedDict([('linear_layer.weight', tensor([[0.7645]])),
#               ('linear_layer.bias', tensor([0.8300]))]))

# %%
next(model_1.parameters()).device
# Out:
# device(type='cpu')

# %%
model_1.to(device)
next(model_1.parameters()).device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # Train

# %%
model_1.state_dict()
# Out:
# OrderedDict([('linear_layer.weight', tensor([[0.7645]], device='cuda:0')),
#              ('linear_layer.bias', tensor([0.8300], device='cuda:0'))])

# %%
loss_fn = nn.L1Loss()
optimizer = torch.optim.SGD(params=model_1.parameters(), lr=0.01)

# %%
# seed = 42
epochs = 200

X_train, y_train, X_test, y_test = X_train.to(device), y_train.to(device), X_test.to(device), y_test.to(device)

for epoch in range(epochs):
    model_1.train()
    y_pred = model_1(X_train)
    loss = loss_fn(y_pred, y_train)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    model_1.eval()
    with torch.inference_mode():
        test_pred = model_1(X_test)
        test_loss = loss_fn(test_pred, y_test)

    if epoch % 10 == 0:
        print(f"Epoch: {epoch} | Loss: {loss} | test_loss: {test_loss}")
# Out:
# Epoch: 0 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 10 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 20 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 30 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 40 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 50 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 60 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 70 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 80 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 90 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 100 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 110 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 120 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 130 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 140 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 150 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 160 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 170 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 180 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882
# Epoch: 190 | Loss: 0.0012645035749301314 | test_loss: 0.013801801018416882

# %%
model_1.state_dict()
# Out:
# OrderedDict([('linear_layer.weight', tensor([[0.6968]], device='cuda:0')),
#              ('linear_layer.bias', tensor([0.3025], device='cuda:0'))])

# %% [markdown]
# # Test Part

# %%
model_1.eval()
with torch.inference_mode():
    y_pred = model_1(X_test)
y_pred
# Out:
# tensor([[0.8600],
#         [0.8739],
#         [0.8878],
#         [0.9018],
#         [0.9157],
#         [0.9296],
#         [0.9436],
#         [0.9575],
#         [0.9714],
#         [0.9854]], device='cuda:0')

# %%
nnn.plot_predictions(train=[X_train.cpu(),y_train.cpu()], test=[X_test.cpu(),y_test.cpu()], prediction=y_pred.cpu())

# %% [markdown]
# # saving

# %%
from pathlib import Path
model_path = Path("models")
model_path.mkdir(parents=True, exist_ok=True)
model_name = "01_python_workflow.pth"
model_save_path = model_path / model_name
print(f"saving model in {model_path}")
torch.save(obj=model_1.state_dict(), f=model_save_path)
print(f"saved successfully.")
# Out:
# saving model in models
# saved successfully.

# %% [markdown]
# # load

# %%
loaded_model = Linear()
loaded_model.load_state_dict(torch.load(model_save_path))
next(loaded_model.parameters()).device
# Out:
# device(type='cpu')

# %%
loaded_model.to(device)
loaded_model.eval()
loss_fn = nn.L1Loss()
with torch.inference_mode():
    pred = loaded_model(X_test)
    loss = loss_fn(pred, y_test)

print(loss)
# Out:
# tensor(0.0003, device='cuda:0')

# %%
y_test
# Out:
# tensor([[0.8600],
#         [0.8740],
#         [0.8880],
#         [0.9020],
#         [0.9160],
#         [0.9300],
#         [0.9440],
#         [0.9580],
#         [0.9720],
#         [0.9860]], device='cuda:0')
